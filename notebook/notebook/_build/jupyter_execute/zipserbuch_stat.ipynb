# %% [markdown]
# # Lőcsei demográfiai változások 1620-1667 között

# %%
import pandas
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
from ipydatagrid import DataGrid
import ipywidgets as widgets
from ipywidgets import interactive
from ipywidgets import interact


records = pandas.read_excel('nevsor.xlsx')

records.head(5)
# Out:
#   lőcsei családok 1600 lőcsei családok 1667
# 0           Abscheimen                Aaron
# 1             Abzieher         Abrachamides
# 2              Audrich              Achband
# 3                 Bank                 Adam
# 4                Bardt                Adami

# %%
citizens = pandas.read_excel('szemelyek.xlsx')
citizens.head()
# Out:
#    id                                                név születési hely  \
# 0   1  [szervezet] a besztercebányai evangélikus isko...            NaN
# 1   2  [szervezet] a lőcsei evangélikus gimnázium elő...            NaN
# 2   3  [szervezet] a lőcsei evangélikus gimnázium ünn...            NaN
# 3   4  [szervezet] a lőcsei evangélikus gimnázium viz...            NaN
# 4   5  [szervezet] a lőcsei evangélikus gimnázium viz...            NaN
#
#   névváltozat foglalkozás életrajzi hivatkozás  \
# 0         NaN      vizsga                  NaN
# 1         NaN     program                  NaN
# 2         NaN     program                  NaN
# 3         NaN      vizsga                  NaN
# 4         NaN      vizsga                  NaN
#
#                                         rövid leírás RMNy (alkalmi)
# 0  A tételeket 1642 májusában vitatták meg a besz...           1934
# 1  Meghívó a lőcsei evangélikus gimnázium hallgat...           2223
# 2  A lőcsei evangélikus gimnázium 1666. január 30...           3295
# 3  A nyomtatvány a lőcsei evangélikus gimnázium 1...           3296
# 4  1646. szeptember 9. A tételeket szeptember 25-...           2147

# %% [markdown]
# Az alábbiakban két külön listába szedem az 1600-as névsort és az 1667-es névsort, majd a listákat metszem a Python beépített halmazkezelő függvényeivel. Ezekből az adatokból, a listák méretét megadva 2-elemű Venn-diagrammot tudunk készíteni a matplotlib-re épülő matplotlib-venn könyvtár segítségével.

# %%
list_1620 = records['lőcsei családok 1600'].dropna().values.tolist()
list_1667 = records['lőcsei családok 1667'].dropna().values.tolist()
list_intersection = list(set(list_1620).intersection(list_1667))


venn2(subsets = (len(list_1620), len(list_1667), len(list_intersection)), set_labels = ('1620', '1667'))
plt.show()

# %% [markdown]
# A következőkben egy új adatstruktúrát határozunk meg, amiben az összes lőcse polgári családnév szerepel, majd összevetjük a polgárok névsorával.

# %%
def find_in_citizen_records(name):
    index_name = citizens['név'].str.contains(name, na=False)
    index_alt_name = citizens['névváltozat'].str.contains(name, na=False)
    
    index_list = citizens[index_name]
    index_alt_list = citizens[index_alt_name]
    number_of_records =  len(index_list) + len(index_alt_list)
    
    return number_of_records
        
list_of_names = []
for item in list_1620:
    record = {}
    record['name'] = item
    record['records'] = find_in_citizen_records(item)
    record['year'] = '1620'
    list_of_names.append(record)
    
for item in list_intersection:
    record = {}
    record['name'] = item
    record['records'] = find_in_citizen_records(item)
    record['year'] = 'both'
    list_of_names.append(record)
    
for item in list_1667:
    record = {}
    record['name'] = item
    record['records'] = find_in_citizen_records(item)
    record['year'] = '1667'
    list_of_names.append(record)


df = pandas.DataFrame.from_records(list_of_names)
df.head()
# Out:
#          name  records  year
# 0  Abscheimen        0  1620
# 1    Abzieher        0  1620
# 2     Audrich        0  1620
# 3        Bank        0  1620
# 4       Bardt        0  1620

# %% [markdown]
# A következőben egy megjelenítőt készítünk az így létrejött adatstruktúrának.

# %%
df = df.sort_values(by=['records'], ascending=False)
df = df.style.set_caption("A nyomtatványok között leggyakrabban előforduló családnevek")
df
# Out:
# <style type="text/css">
# </style>
# <table id="T_7db65">
#   <caption>A nyomtatványok között leggyakrabban előforduló családnevek</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7db65_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_7db65_level0_col1" class="col_heading level0 col1" >records</th>
#       <th id="T_7db65_level0_col2" class="col_heading level0 col2" >year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7db65_level0_row0" class="row_heading level0 row0" >574</th>
#       <td id="T_7db65_row0_col0" class="data row0 col0" >Johan</td>
#       <td id="T_7db65_row0_col1" class="data row0 col1" >68</td>
#       <td id="T_7db65_row0_col2" class="data row0 col2" >1667</td>
#     </tr>
#     <tr>
#       <th id="T_7db65_level0_row1" class="row_heading level0 row1" >446</th>
#       <td id="T_7db65_row1_col0" class="data row1 col0" >Christ</td>
#       <td id="T_7db65_row1_col1" class="data row1 col1" >30</td>
#       <td id="T_7db65_row1_col2" class="data row1 col2" >1667</td>
#     </tr>
#     <tr>
#       <th id="T_7db65_level0_row2" class="row_heading level0 row2" >414</th>
#       <td id="T_7db65_row2_col0" class="data row2 col0" >Adam</td>
#       <td id="T_7db65_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_7db65_row2_col2" class="data row2 col2" >1667</td>
#     </tr>
#     <tr>
#       <th id="T_7db65_level0_row3" class="row_heading level0 row3" >628</th>
#       <td id="T_7db65_row3_col0" class="data row3 col0" >Lang</td>
#       <td id="T_7db65_row3_col1" class="data row3 col1" >12</td>
#       <td id="T_7db65_row3_col2" class="data row3 col2" >1667</td>
#     </tr>
#     <tr>
#       <th id="T_7db65_level0_row4" class="row_heading level0 row4" >173</th>
#       <td id="T_7db65_row4_col0" class="data row4 col0" >Lang</td>
#       <td id="T_7db65_row4_col1" class="data row4 col1" >12</td>
#       <td id="T_7db65_row4_col2" class="data row4 col2" >1620</td>
#     </tr>
#     <tr>
#       <th id="T_7db65_level0_row5" class="row_heading level0 row5" >389</th>
#       <td id="T_7db65_row5_col0" class="data row5 col0" >Lang</td>
#       <td id="T_7db65_row5_col1" class="data row5 col1" >12</td>
#       <td id="T_7db65_row5_col2" class="data row5 col2" >both</td>
#     </tr>
#     <tr>
#       <th id="T_7db65_level0_row6" class="row_heading level0 row6" >449</th>
#       <td id="T_7db65_row6_col0" class="data row6 col0" >Cramer</td>
#       <td id="T_7db65_row6_col1" class="data row6 col1" >8</td>
#       <td id="T_7db65_row6_col2" class="data row6 col2" >1667</td>
#     </tr>
#     <tr>
#       <th id="T_7db65_level0_row7" class="row_heading level0 row7" >533</th>
#       <td id="T_7db65_row7_col0" class="data row7 col0" >Günther</td>
#       <td id="T_7db65_row7_col1" class="data row7 col1" >6</td>
#       <td id="T_7db65_row7_col2" class="data row7 col2" >1667</td>
#     </tr>
#     <tr>
#       <th id="T_7db65_level0_row8" class="row_heading level0 row8" >418</th>
#       <td id="T_7db65_row8_col0" class="data row8 col0" >Alauda</td>
#       <td id="T_7db65_row8_col1" class="data row8 col1" >5</td>
#       <td id="T_7db65_row8_col2" class="data row8 col2" >1667</td>
#     </tr>
#     <tr>
#       <th id="T_7db65_level0_row9" class="row_heading level0 row9" >450</th>
#       <td id="T_7db65_row9_col0" class="data row9 col0" >Croner</td>
#       <td id="T_7db65_row9_col1" class="data row9 col1" >5</td>
#       <td id="T_7db65_row9_col2" class="data row9 col2" >1667</td>
#     </tr>
#     <tr>
#       <th id="T_7db65_level0_row10" class="row_heading level0 row10" >6</th>
#       <td id="T_7db65_row10_col0" class="data row10 col0" >Ber</td>
#       <td id="T_7db65_row10_col1" class="data row10 col1" >5</td>
#       <td id="T_7db65_row10_col2" class="data row10 col2" >1620</td>
#     </tr>
#     <tr>
#       <th id="T_7db65_level0_row11" class="row_heading level0 row11" >535</th>
#       <td id="T_7db65_row11_col0" class="data row11 col0" >Han</td>
#       <td id="T_7db65_row11_col1" class="data row11 col1" >5</td>
#       <td id="T_7db65_row11_col2" class="data row11 col2" >1667</td>
#     </tr>
#     <tr>
#       <th id="T_7db65_level0_row12" class="row_heading level0 row12" >352</th>
#       <td id="T_7db65_row12_col0" class="data row12 col0" >Windisch</td>
#       <td id="T_7db65_row12_col1" class="data row12 col1" >4</td>
#       <td id="T_7db65_row12_col2" class="data row12 col2" >1620</td>
#     </tr>
#     <tr>
#       <th id="T_7db65_level0_row13" class="row_heading level0 row13" >399</th>
#       <td id="T_7db65_row13_col0" class="data row13 col0" >Windisch</td>
#       <td id="T_7db65_row13_col1" class="data row13 col1" >4</td>
#       <td id="T_7db65_row13_col2" class="data row13 col2" >both</td>
#     </tr>
#     <tr>
#       <th id="T_7db65_level0_row14" class="row_heading level0 row14" >822</th>
#       <td id="T_7db65_row14_col0" class="data row14 col0" >Windisch</td>
#       <td id="T_7db65_row14_col1" class="data row14 col1" >4</td>
#       <td id="T_7db65_row14_col2" class="data row14 col2" >1667</td>
#     </tr>
#     <tr>
#       <th id="T_7db65_level0_row15" class="row_heading level0 row15" >616</th>
#       <td id="T_7db65_row15_col0" class="data row15 col0" >Kretschmer</td>
#       <td id="T_7db65_row15_col1" class="data row15 col1" >3</td>
#       <td id="T_7db65_row15_col2" class="data row15 col2" >1667</td>
#     </tr>
#     <tr>
#       <th id="T_7db65_level0_row16" class="row_heading level0 row16" >415</th>
#       <td id="T_7db65_row16_col0" class="data row16 col0" >Adami</td>
#       <td id="T_7db65_row16_col1" class="data row16 col1" >3</td>
#       <td id="T_7db65_row16_col2" class="data row16 col2" >1667</td>
#     </tr>
#     <tr>
#       <th id="T_7db65_level0_row17" class="row_heading level0 row17" >123</th>
#       <td id="T_7db65_row17_col0" class="data row17 col0" >István</td>
#       <td id="T_7db65_row17_col1" class="data row17 col1" >3</td>
#       <td id="T_7db65_row17_col2" class="data row17 col2" >1620</td>
#     </tr>
#     <tr>
#       <th id="T_7db65_level0_row18" class="row_heading level0 row18" >829</th>
#       <td id="T_7db65_row18_col0" class="data row18 col0" >Wolfgang</td>
#       <td id="T_7db65_row18_col1" class="data row18 col1" >3</td>
#       <td id="T_7db65_row18_col2" class="data row18 col2" >1667</td>
#     </tr>
#     <tr>
#       <th id="T_7db65_level0_row19" class="row_heading level0 row19" >760</th>
#       <td id="T_7db65_row19_col0" class="data row19 col0" >Sontag</td>
#       <td id="T_7db65_row19_col1" class="data row19 col1" >3</td>
#       <td id="T_7db65_row19_col2" class="data row19 col2" >1667</td>
#     </tr>
#     <tr>
#       <th id="T_7db65_level0_row20" class="row_heading level0 row20" >486</th>
#       <td id="T_7db65_row20_col0" class="data row20 col0" >Finck</td>
#       <td id="T_7db65_row20_col1" class="data row20 col1" >3</td>
#       <td id="T_7db65_row20_col2" class="data row20 col2" >1667</td>
#     </tr>
#     <tr>
#       <th id="T_7db65_level0_row21" class="row_heading level0 row21" >761</th>
#       <td id="T_7db65_row21_col0" class="data row21 col0" >Söldner</td>
#       <td id="T_7db65_row21_col1" class="data row21 col1" >3</td>
#       <td id="T_7db65_row21_col2" class="data row21 col2" >1667</td>
#     </tr>
#     <tr>
#       <th id="T_7db65_level0_row22" class="row_heading level0 row22" >571</th>
#       <td id="T_7db65_row22_col0" class="data row22 col0" >Jakob</td>
#       <td id="T_7db65_row22_col1" class="data row22 col1" >3</td>
#       <td id="T_7db65_row22_col2" class="data row22 col2" >1667</td>
#     </tr>
#     <tr>
#       <th id="T_7db65_level0_row23" class="row_heading level0 row23" >156</th>
#       <td id="T_7db65_row23_col0" class="data row23 col0" >Kramer</td>
#       <td id="T_7db65_row23_col1" class="data row23 col1" >2</td>
#       <td id="T_7db65_row23_col2" class="data row23 col2" >1620</td>
#     </tr>
#     <tr>
#       <th id="T_7db65_level0_row24" class="row_heading level0 row24" >146</th>
#       <td id="T_7db65_row24_col0" class="data row24 col0" >Klem</td>
#       <td id="T_7db65_row24_col1" class="data row24 col1" >2</td>
#       <td id="T_7db65_row24_col2" class="data row24 col2" >1620</td>
#     </tr>
#     <tr>
#       <
